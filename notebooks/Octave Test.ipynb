# %% [markdown]
# # Octave Test

# %%
from pathfinder import Pathfinder

# abs_paths = ['']
# relative_paths = Pathfinder.relative_paths_from_abs(abs_paths)

# %%
relative_paths = [['..', '..', '..', '..', '..', '..', '資料科學', 'Allen Downey', 'Think DSP', 'code'], 
                  ['..', '..', '..', '..', 'AutoEq'],
                  ['..', 'codes']]

Pathfinder.append_relative_paths(relative_paths)

# %%
# %pylab inline 

from drc.measurements.frequency import Octave
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Spectrum

# %%
bands = Octave.get_octave_by_bands(5)
bands
# Out:
# array([[8.43393007e+00, 2.00000000e+01, 4.74274741e+01, 5.12905418e-01],
#        [4.74274741e+01, 1.12468265e+02, 2.66704286e+02, 5.12905418e-01],
#        [2.66704286e+02, 6.32455532e+02, 1.49978842e+03, 5.12905418e-01],
#        [1.49978842e+03, 3.55655882e+03, 8.43393007e+03, 5.12905418e-01],
#        [8.43393007e+03, 2.00000000e+04, 4.74274741e+04, 5.12905418e-01]])

# %%
bands = Octave.get_octave_by_bands(10)
bands
# Out:
# array([[1.36258414e+01, 2.00000000e+01, 2.93559854e+01, 1.27144418e+00],
#        [2.93559854e+01, 4.30886938e+01, 6.32455532e+01, 1.27144418e+00],
#        [6.32455532e+01, 9.28317767e+01, 1.36258414e+02, 1.27144418e+00],
#        [1.36258414e+02, 2.00000000e+02, 2.93559854e+02, 1.27144418e+00],
#        [2.93559854e+02, 4.30886938e+02, 6.32455532e+02, 1.27144418e+00],
#        [6.32455532e+02, 9.28317767e+02, 1.36258414e+03, 1.27144418e+00],
#        [1.36258414e+03, 2.00000000e+03, 2.93559854e+03, 1.27144418e+00],
#        [2.93559854e+03, 4.30886938e+03, 6.32455532e+03, 1.27144418e+00],
#        [6.32455532e+03, 9.28317767e+03, 1.36258414e+04, 1.27144418e+00],
#        [1.36258414e+04, 2.00000000e+04, 2.93559854e+04, 1.27144418e+00]])

# %%
bands = Octave.get_octave_by_bands(15, 25, 16000)
bands
# Out:
# array([[1.98481163e+01, 2.50000000e+01, 3.14891344e+01, 2.14757848e+00],
#        [3.14891344e+01, 3.96626233e+01, 4.99576670e+01, 2.14757848e+00],
#        [4.99576670e+01, 6.29249475e+01, 7.92580851e+01, 2.14757848e+00],
#        [7.92580851e+01, 9.98307396e+01, 1.25743343e+02, 2.14757848e+00],
#        [1.25743343e+02, 1.58381961e+02, 1.99492434e+02, 2.14757848e+00],
#        [1.99492434e+02, 2.51273762e+02, 3.16495730e+02, 2.14757848e+00],
#        [3.16495730e+02, 3.98647063e+02, 5.02122037e+02, 2.14757848e+00],
#        [5.02122037e+02, 6.32455532e+02, 7.96619089e+02, 2.14757848e+00],
