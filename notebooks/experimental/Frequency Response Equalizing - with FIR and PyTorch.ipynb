# %% [markdown]
# # Frequency Response Equalizing - with FIR and PyTorch
# ### with TCPi Channel and ESP32 as Server

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from pathfinder import Pathfinder

# abs_paths = [' ']
# Pathfinder.relative_paths_from_abs(abs_paths)
 
relative_paths = [['..', '..', '..', '..', '..', 'SigmaDSP', 'bitbucket', 'github', 'codes'],
                  ['..', '..', '..', '..', '..', 'Signal Generators', 'bitbucket', 'github', 'codes'],
                  ['..', '..', '..', '..', '..', 'Utilities', 'bitbucket', 'github', 'codes'], 
                  ['..', '..', '..', '..', '..', 'TCPi', 'bitbucket', 'github', 'codes']] 

Pathfinder.append_relative_paths(relative_paths)
# =====================================================

import pandas as pd

#https://thispointer.com/python-pandas-how-to-display-full-dataframe-i-e-print-all-rows-columns-without-truncation/
pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)
# =====================================================

## TCPi

import time 

from tcpi.protocols.TCPIP1701 import class_finder
# =====================================================

### Client

from tcpi.bus.tcpi_client import I2C as TcpI2C_client

tcpi_client = TcpI2C_client(class_finder)
server_ip = '192.168.228.36'
tcpi_client.connect(server_ip = server_ip, server_port = 8086)
time.sleep(1)
# =====================================================

## DSP processor

from sigma.sigma_dsp.adau import ADAU1401

# dsp = ADAU1401(bus = bus)
dsp = ADAU1401(bus = tcpi_client)
# =====================================================

def reset_dsp():
    CMD_RESET_DSP = b'Reset_DSP'
    tcpi_client.send(CMD_RESET_DSP)
    time.sleep(0.5)    

reset_dsp()
# Out:
# [Connecting server: ('192.168.228.36', 8086)]
#
# [Connected with server: ('192.168.228.36', 8086)]

# %% [markdown]
# ### Reset if needed

# %%
# CMD_RESET = b'Reset'

# tcpi_client.send(CMD_RESET)

# %%
# tcpi_client.connect(server_ip = server_ip, server_port = 8086)

# %%
# tcpi_client.set_server_property('name', 'Stereo Speakers')

# %%
# tcpi_client.get_server_property('name')

# %%
# servers = {}
# servers[tcpi_client.get_server_property('name')] = tcpi_client.socket.getpeername()
# servers

# %% [markdown]
# ## SigmaStudio project file

# %%
import os

SigmaStudio_project_file_url = os.sep.join(['..', 'SigmaStudio projects', 'projects', 'demo', 'demo.dspproj'])
SigmaStudio_project_file_url
# Out:
# '..\\SigmaStudio projects\\projects\\demo\\demo.dspproj'

# %% [markdown]
# ![](https://github.com/Wei1234c/DRC/blob/master/SigmaStudio%20projects/projects/demo/demo.png?raw=true)

# %% [markdown]
# ## Factory

# %%
import os
from sigma.factory import Factory 

project_xml_file_url = os.sep.join(['..', '..', 'SigmaStudio projects', 'projects', 'demo', 'demo.xml'])
class_files_root_url = os.sep.join(['..', '..', '..', '..', '..', 'SigmaDSP', 'bitbucket', 'github', 'codes', 'sigma', 'sigma_studio', 'toolbox', 'cells']) 

factory = Factory(project_xml_file_url = project_xml_file_url,
                  class_files_root_url = class_files_root_url,
                  dsp = dsp
                 )

# %% [markdown]
# ## IC

# %%
# showing cells, algorithms, parameters of this project

ic = factory.get_ic()
ic.df
# Out:
#                                                                                          param_full_name  \
# algorithm_name              cell_name     param_name
# EQ1940Invert                Invert0       gain                                         EQ1940Invert1gain
#                             Invert1       gain                                         EQ1940Invert2gain
# FIRFiltAlg                  FIR0          fircoeff_0                               FIRFiltAlg1fircoeff_0
#                             FIR1          fircoeff_0                               FIRFiltAlg2fircoeff_0
# Gain1940AlgNS               Gain0                                                         Gain1940AlgNS2
#                             Gain1                                                         Gain1940AlgNS1
# MultCtrlFracDelGrowFixedAlg Delay0                                          MultCtrlFracDelGrowFixedAlg1
#                                           Limit1buffersize  MultCtrlFracDelGrowFixedAlg1Limit1buffersize
#                             Delay1                                          MultCtrlFracDelGrowFixedAlg2
#                                           Limit1buffersize  MultCtrlFracDelGrowFixedAlg2Limit1buffersize
# MuteNoSlewAlg               Mute00        mute                                        MuteNoSlewAlg1mute
#                             Mute01        mute                                        MuteNoSlewAlg2mute
#                             Mute10        mute                                        MuteNoSlewAlg3mute
#                             Mute11        mute                                        MuteNoSlewAlg4mute
# PEQ1Chan                    Param EQ0     0B1                                               PEQ1Chan20B1
#                                           0B10                                             PEQ1Chan20B10
#                                           0B2                                               PEQ1Chan20B2
#                                           0B3                                               PEQ1Chan20B3
#                                           0B4                                               PEQ1Chan20B4
#                                           0B5                                               PEQ1Chan20B5
#                                           0B6                                               PEQ1Chan20B6
#                                           0B7                                               PEQ1Chan20B7
#                                           0B8                                               PEQ1Chan20B8
#                                           0B9                                               PEQ1Chan20B9
#                                           1A1                                               PEQ1Chan21A1
#                                           1A10                                             PEQ1Chan21A10
#                                           1A2                                               PEQ1Chan21A2
#                                           1A3                                               PEQ1Chan21A3
#                                           1A4                                               PEQ1Chan21A4
#                                           1A5                                               PEQ1Chan21A5
#                                           1A6                                               PEQ1Chan21A6
#                                           1A7                                               PEQ1Chan21A7
#                                           1A8                                               PEQ1Chan21A8
#                                           1A9                                               PEQ1Chan21A9
#                                           1B1                                               PEQ1Chan21B1
#                                           1B10                                             PEQ1Chan21B10
#                                           1B2                                               PEQ1Chan21B2
#                                           1B3                                               PEQ1Chan21B3
#                                           1B4                                               PEQ1Chan21B4
#                                           1B5                                               PEQ1Chan21B5
#                                           1B6                                               PEQ1Chan21B6
#                                           1B7                                               PEQ1Chan21B7
#                                           1B8                                               PEQ1Chan21B8
#                                           1B9                                               PEQ1Chan21B9
#                                           2A1                                               PEQ1Chan22A1
#                                           2A10                                             PEQ1Chan22A10
#                                           2A2                                               PEQ1Chan22A2
#                                           2A3                                               PEQ1Chan22A3
#                                           2A4                                               PEQ1Chan22A4
#                                           2A5                                               PEQ1Chan22A5
#                                           2A6                                               PEQ1Chan22A6
#                                           2A7                                               PEQ1Chan22A7
#                                           2A8                                               PEQ1Chan22A8
#                                           2A9                                               PEQ1Chan22A9
#                                           2B1                                               PEQ1Chan22B1
#                                           2B10                                             PEQ1Chan22B10
#                                           2B2                                               PEQ1Chan22B2
#                                           2B3                                               PEQ1Chan22B3
#                                           2B4                                               PEQ1Chan22B4
#                                           2B5                                               PEQ1Chan22B5
#                                           2B6                                               PEQ1Chan22B6
#                                           2B7                                               PEQ1Chan22B7
#                                           2B8                                               PEQ1Chan22B8
#                                           2B9                                               PEQ1Chan22B9
#                             Param EQ1     0B1                                               PEQ1Chan30B1
#                                           0B10                                             PEQ1Chan30B10
#                                           0B2                                               PEQ1Chan30B2
#                                           0B3                                               PEQ1Chan30B3
#                                           0B4                                               PEQ1Chan30B4
#                                           0B5                                               PEQ1Chan30B5
#                                           0B6                                               PEQ1Chan30B6
#                                           0B7                                               PEQ1Chan30B7
#                                           0B8                                               PEQ1Chan30B8
#                                           0B9                                               PEQ1Chan30B9
#                                           1A1                                               PEQ1Chan31A1
#                                           1A10                                             PEQ1Chan31A10
#                                           1A2                                               PEQ1Chan31A2
#                                           1A3                                               PEQ1Chan31A3
#                                           1A4                                               PEQ1Chan31A4
#                                           1A5                                               PEQ1Chan31A5
#                                           1A6                                               PEQ1Chan31A6
#                                           1A7                                               PEQ1Chan31A7
#                                           1A8                                               PEQ1Chan31A8
#                                           1A9                                               PEQ1Chan31A9
#                                           1B1                                               PEQ1Chan31B1
#                                           1B10                                             PEQ1Chan31B10
#                                           1B2                                               PEQ1Chan31B2
#                                           1B3                                               PEQ1Chan31B3
#                                           1B4                                               PEQ1Chan31B4
#                                           1B5                                               PEQ1Chan31B5
#                                           1B6                                               PEQ1Chan31B6
#                                           1B7                                               PEQ1Chan31B7
#                                           1B8                                               PEQ1Chan31B8
#                                           1B9                                               PEQ1Chan31B9
#                                           2A1                                               PEQ1Chan32A1
#                                           2A10                                             PEQ1Chan32A10
#                                           2A2                                               PEQ1Chan32A2
#                                           2A3                                               PEQ1Chan32A3
#                                           2A4                                               PEQ1Chan32A4
#                                           2A5                                               PEQ1Chan32A5
#                                           2A6                                               PEQ1Chan32A6
#                                           2A7                                               PEQ1Chan32A7
#                                           2A8                                               PEQ1Chan32A8
#                                           2A9                                               PEQ1Chan32A9
#                                           2B1                                               PEQ1Chan32B1
#                                           2B10                                             PEQ1Chan32B10
#                                           2B2                                               PEQ1Chan32B2
#                                           2B3                                               PEQ1Chan32B3
#                                           2B4                                               PEQ1Chan32B4
#                                           2B5                                               PEQ1Chan32B5
#                                           2B6                                               PEQ1Chan32B6
#                                           2B7                                               PEQ1Chan32B7
#                                           2B8                                               PEQ1Chan32B8
#                                           2B9                                               PEQ1Chan32B9
# PinkFAlg                    Pink Flt1     coeff0a                                       PinkFAlg1coeff0a
#                                           input_gain                                 PinkFAlg1input_gain
#                                           output_gain                               PinkFAlg1output_gain
# SingleCtrlMixer             Merger0                                                 SingleCtrlMixer19401
#                             Merger1                                                 SingleCtrlMixer19402
# StMuxSwSlew                 Source_Switch coeffname                                StMuxSwSlew1coeffname
# WhiteNAlgNew                White_Noise   enable                                     WhiteNAlgNew1enable
#                                           mxx                                           WhiteNAlgNew1mxx
# monoMuxSwSlew               SW_noise      coeffname                              monoMuxSwSlew1coeffname
# sin_lookupAlg               Tone          increment                          sin_lookupAlg19401increment
#                                           ison                                    sin_lookupAlg19401ison
#                                           mask                                    sin_lookupAlg19401mask
#
#                                                              type  \
# algorithm_name              cell_name     param_name
# EQ1940Invert                Invert0       gain              float
#                             Invert1       gain              float
# FIRFiltAlg                  FIR0          fircoeff_0        bytes
#                             FIR1          fircoeff_0        bytes
# Gain1940AlgNS               Gain0                           float
#                             Gain1                           float
# MultCtrlFracDelGrowFixedAlg Delay0                          float
#                                           Limit1buffersize    int
#                             Delay1                          float
#                                           Limit1buffersize    int
# MuteNoSlewAlg               Mute00        mute              float
#                             Mute01        mute              float
#                             Mute10        mute              float
#                             Mute11        mute              float
# PEQ1Chan                    Param EQ0     0B1               float
#                                           0B10              float
#                                           0B2               float
#                                           0B3               float
#                                           0B4               float
#                                           0B5               float
#                                           0B6               float
#                                           0B7               float
#                                           0B8               float
#                                           0B9               float
#                                           1A1               float
#                                           1A10              float
#                                           1A2               float
#                                           1A3               float
#                                           1A4               float
#                                           1A5               float
#                                           1A6               float
#                                           1A7               float
#                                           1A8               float
#                                           1A9               float
#                                           1B1               float
#                                           1B10              float
#                                           1B2               float
#                                           1B3               float
#                                           1B4               float
#                                           1B5               float
#                                           1B6               float
#                                           1B7               float
#                                           1B8               float
#                                           1B9               float
#                                           2A1               float
#                                           2A10              float
#                                           2A2               float
#                                           2A3               float
#                                           2A4               float
#                                           2A5               float
#                                           2A6               float
#                                           2A7               float
#                                           2A8               float
#                                           2A9               float
#                                           2B1               float
#                                           2B10              float
#                                           2B2               float
#                                           2B3               float
#                                           2B4               float
#                                           2B5               float
#                                           2B6               float
#                                           2B7               float
#                                           2B8               float
#                                           2B9               float
#                             Param EQ1     0B1               float
#                                           0B10              float
#                                           0B2               float
#                                           0B3               float
#                                           0B4               float
#                                           0B5               float
#                                           0B6               float
#                                           0B7               float
#                                           0B8               float
#                                           0B9               float
#                                           1A1               float
#                                           1A10              float
#                                           1A2               float
#                                           1A3               float
#                                           1A4               float
#                                           1A5               float
#                                           1A6               float
#                                           1A7               float
#                                           1A8               float
#                                           1A9               float
#                                           1B1               float
#                                           1B10              float
#                                           1B2               float
#                                           1B3               float
#                                           1B4               float
#                                           1B5               float
#                                           1B6               float
#                                           1B7               float
#                                           1B8               float
#                                           1B9               float
#                                           2A1               float
#                                           2A10              float
#                                           2A2               float
#                                           2A3               float
#                                           2A4               float
#                                           2A5               float
#                                           2A6               float
#                                           2A7               float
#                                           2A8               float
#                                           2A9               float
#                                           2B1               float
#                                           2B10              float
#                                           2B2               float
#                                           2B3               float
#                                           2B4               float
#                                           2B5               float
#                                           2B6               float
#                                           2B7               float
#                                           2B8               float
#                                           2B9               float
# PinkFAlg                    Pink Flt1     coeff0a           bytes
#                                           input_gain        float
#                                           output_gain       float
# SingleCtrlMixer             Merger0                         float
#                             Merger1                         float
# StMuxSwSlew                 Source_Switch coeffname           int
# WhiteNAlgNew                White_Noise   enable            float
#                                           mxx                 int
# monoMuxSwSlew               SW_noise      coeffname           int
# sin_lookupAlg               Tone          increment         float
#                                           ison              float
#                                           mask                int
#
#                                                                     value  \
# algorithm_name              cell_name     param_name
# EQ1940Invert                Invert0       gain                  -1.000000
#                             Invert1       gain                   1.000000
# FIRFiltAlg                  FIR0          fircoeff_0                  NaN
#                             FIR1          fircoeff_0                  NaN
# Gain1940AlgNS               Gain0                                1.000000
#                             Gain1                                1.000000
# MultCtrlFracDelGrowFixedAlg Delay0                               0.000000
#                                           Limit1buffersize     140.000000
#                             Delay1                               0.000000
#                                           Limit1buffersize     140.000000
# MuteNoSlewAlg               Mute00        mute                   1.000000
#                             Mute01        mute                   0.000000
#                             Mute10        mute                   0.000000
#                             Mute11        mute                   1.000000
# PEQ1Chan                    Param EQ0     0B1                    1.000000
#                                           0B10                   1.000000
#                                           0B2                    1.000000
#                                           0B3                    1.000000
#                                           0B4                    1.000000
#                                           0B5                    1.000000
#                                           0B6                    1.000000
#                                           0B7                    1.000000
#                                           0B8                    1.000000
#                                           0B9                    1.000000
#                                           1A1                    0.000000
#                                           1A10                   0.000000
#                                           1A2                    0.000000
#                                           1A3                    0.000000
#                                           1A4                    0.000000
#                                           1A5                    0.000000
#                                           1A6                    0.000000
#                                           1A7                    0.000000
#                                           1A8                    0.000000
#                                           1A9                    0.000000
#                                           1B1                    0.000000
#                                           1B10                   0.000000
#                                           1B2                    0.000000
#                                           1B3                    0.000000
#                                           1B4                    0.000000
#                                           1B5                    0.000000
#                                           1B6                    0.000000
#                                           1B7                    0.000000
#                                           1B8                    0.000000
#                                           1B9                    0.000000
#                                           2A1                    0.000000
#                                           2A10                   0.000000
#                                           2A2                    0.000000
#                                           2A3                    0.000000
#                                           2A4                    0.000000
#                                           2A5                    0.000000
#                                           2A6                    0.000000
#                                           2A7                    0.000000
#                                           2A8                    0.000000
#                                           2A9                    0.000000
#                                           2B1                    0.000000
#                                           2B10                   0.000000
#                                           2B2                    0.000000
#                                           2B3                    0.000000
#                                           2B4                    0.000000
#                                           2B5                    0.000000
#                                           2B6                    0.000000
#                                           2B7                    0.000000
#                                           2B8                    0.000000
#                                           2B9                    0.000000
#                             Param EQ1     0B1                    1.000000
#                                           0B10                   1.000000
#                                           0B2                    1.000000
#                                           0B3                    1.000000
#                                           0B4                    1.000000
#                                           0B5                    1.000000
#                                           0B6                    1.000000
#                                           0B7                    1.000000
#                                           0B8                    1.000000
#                                           0B9                    1.000000
#                                           1A1                    0.000000
#                                           1A10                   0.000000
#                                           1A2                    0.000000
#                                           1A3                    0.000000
#                                           1A4                    0.000000
#                                           1A5                    0.000000
#                                           1A6                    0.000000
#                                           1A7                    0.000000
#                                           1A8                    0.000000
#                                           1A9                    0.000000
#                                           1B1                    0.000000
#                                           1B10                   0.000000
#                                           1B2                    0.000000
#                                           1B3                    0.000000
#                                           1B4                    0.000000
#                                           1B5                    0.000000
#                                           1B6                    0.000000
#                                           1B7                    0.000000
#                                           1B8                    0.000000
#                                           1B9                    0.000000
#                                           2A1                    0.000000
#                                           2A10                   0.000000
#                                           2A2                    0.000000
#                                           2A3                    0.000000
#                                           2A4                    0.000000
#                                           2A5                    0.000000
#                                           2A6                    0.000000
#                                           2A7                    0.000000
#                                           2A8                    0.000000
#                                           2A9                    0.000000
#                                           2B1                    0.000000
#                                           2B10                   0.000000
#                                           2B2                    0.000000
#                                           2B3                    0.000000
#                                           2B4                    0.000000
#                                           2B5                    0.000000
#                                           2B6                    0.000000
#                                           2B7                    0.000000
#                                           2B8                    0.000000
#                                           2B9                    0.000000
# PinkFAlg                    Pink Flt1     coeff0a                     NaN
#                                           input_gain             0.312746
#                                           output_gain            1.000000
# SingleCtrlMixer             Merger0                              0.500000
#                             Merger1                              0.500000
# StMuxSwSlew                 Source_Switch coeffname              2.000000
# WhiteNAlgNew                White_Noise   enable                 1.000000
#                                           mxx               345675.000000
# monoMuxSwSlew               SW_noise      coeffname              1.000000
# sin_lookupAlg               Tone          increment              0.041667
#                                           ison                   1.000000
#                                           mask                 255.000000
#
#                                                             address  n_bytes
# algorithm_name              cell_name     param_name
# EQ1940Invert                Invert0       gain                    5        4
#                             Invert1       gain                   23        4
# FIRFiltAlg                  FIR0          fircoeff_0            137     1024
#                             FIR1          fircoeff_0            393     1024
# Gain1940AlgNS               Gain0                                35        4
#                             Gain1                                36        4
# MultCtrlFracDelGrowFixedAlg Delay0                               32        4
#                                           Limit1buffersize       31        4
#                             Delay1                               34        4
#                                           Limit1buffersize       33        4
# MuteNoSlewAlg               Mute00        mute                   28        4
#                             Mute01        mute                   25        4
#                             Mute10        mute                   27        4
#                             Mute11        mute                   26        4
# PEQ1Chan                    Param EQ0     0B1                    37        4
#                                           0B10                   82        4
#                                           0B2                    42        4
#                                           0B3                    47        4
#                                           0B4                    52        4
#                                           0B5                    57        4
#                                           0B6                    62        4
#                                           0B7                    67        4
#                                           0B8                    72        4
#                                           0B9                    77        4
#                                           1A1                    40        4
#                                           1A10                   85        4
#                                           1A2                    45        4
#                                           1A3                    50        4
#                                           1A4                    55        4
#                                           1A5                    60        4
#                                           1A6                    65        4
#                                           1A7                    70        4
#                                           1A8                    75        4
#                                           1A9                    80        4
#                                           1B1                    38        4
#                                           1B10                   83        4
#                                           1B2                    43        4
#                                           1B3                    48        4
#                                           1B4                    53        4
#                                           1B5                    58        4
#                                           1B6                    63        4
#                                           1B7                    68        4
#                                           1B8                    73        4
#                                           1B9                    78        4
#                                           2A1                    41        4
#                                           2A10                   86        4
#                                           2A2                    46        4
#                                           2A3                    51        4
#                                           2A4                    56        4
#                                           2A5                    61        4
#                                           2A6                    66        4
#                                           2A7                    71        4
#                                           2A8                    76        4
#                                           2A9                    81        4
#                                           2B1                    39        4
#                                           2B10                   84        4
#                                           2B2                    44        4
#                                           2B3                    49        4
#                                           2B4                    54        4
#                                           2B5                    59        4
#                                           2B6                    64        4
#                                           2B7                    69        4
#                                           2B8                    74        4
#                                           2B9                    79        4
#                             Param EQ1     0B1                    87        4
#                                           0B10                  132        4
#                                           0B2                    92        4
#                                           0B3                    97        4
#                                           0B4                   102        4
#                                           0B5                   107        4
#                                           0B6                   112        4
#                                           0B7                   117        4
#                                           0B8                   122        4
#                                           0B9                   127        4
#                                           1A1                    90        4
#                                           1A10                  135        4
#                                           1A2                    95        4
#                                           1A3                   100        4
#                                           1A4                   105        4
#                                           1A5                   110        4
#                                           1A6                   115        4
#                                           1A7                   120        4
#                                           1A8                   125        4
#                                           1A9                   130        4
#                                           1B1                    88        4
#                                           1B10                  133        4
#                                           1B2                    93        4
#                                           1B3                    98        4
#                                           1B4                   103        4
#                                           1B5                   108        4
#                                           1B6                   113        4
#                                           1B7                   118        4
#                                           1B8                   123        4
#                                           1B9                   128        4
#                                           2A1                    91        4
#                                           2A10                  136        4
#                                           2A2                    96        4
#                                           2A3                   101        4
#                                           2A4                   106        4
#                                           2A5                   111        4
#                                           2A6                   116        4
#                                           2A7                   121        4
#                                           2A8                   126        4
#                                           2A9                   131        4
#                                           2B1                    89        4
#                                           2B10                  134        4
#                                           2B2                    94        4
#                                           2B3                    99        4
#                                           2B4                   104        4
#                                           2B5                   109        4
#                                           2B6                   114        4
#                                           2B7                   119        4
#                                           2B8                   124        4
#                                           2B9                   129        4
# PinkFAlg                    Pink Flt1     coeff0a                 6       56
#                                           input_gain             20        4
#                                           output_gain            21        4
# SingleCtrlMixer             Merger0                              30        4
#                             Merger1                              29        4
# StMuxSwSlew                 Source_Switch coeffname              24        4
# WhiteNAlgNew                White_Noise   enable                  0        4
#                                           mxx                     1        4
# monoMuxSwSlew               SW_noise      coeffname              22        4
# sin_lookupAlg               Tone          increment               3        4
#                                           ison                    4        4
#                                           mask                    2        4

# %% [markdown]
# ## Cells

# %%
cells = factory.get_cells(ic)

# %% [markdown]
# ### Get Cell objects ready for use.

# %%
# # un-comment this to generate a script to embody Cell objects.

# for o in factory.get_cells_manifest():
#     print(o)

# %%
# assign variable names to each Cell for easy access.

delay0 = cells['Delay0']  # Fractional Delay( 1 )
delay1 = cells['Delay1']  # Fractional Delay( 1 )
fir0 = cells['FIR0']  # FIR( 1 )
fir1 = cells['FIR1']  # FIR( 1 )
gain0 = cells['Gain0']  # Gain (no slew)( 1 )
gain1 = cells['Gain1']  # Gain (no slew)( 1 )
invert0 = cells['Invert0']  # Invert( 1 )
invert1 = cells['Invert1']  # Invert( 1 )
merger0 = cells['Merger0']  # Signal MixerC
merger1 = cells['Merger1']  # Signal MixerC
mute00 = cells['Mute00']  # No Slew (Standard)( 1 )
mute01 = cells['Mute01']  # No Slew (Standard)( 1 )
mute10 = cells['Mute10']  # No Slew (Standard)( 1 )
mute11 = cells['Mute11']  # No Slew (Standard)( 1 )
param_eq0 = cells['Param EQ0']  # PEQ1Chan - Double Precision( 1 )
param_eq1 = cells['Param EQ1']  # PEQ1Chan - Double Precision( 1 )
pink_flt1 = cells['Pink Flt1']  # Pink Noise Filter( 1 )
source_switch = cells['Source_Switch']  # Stereo SW Slew( 3 )
sw_noise = cells['SW_noise']  # Mono SW Slew( 2 )
tone = cells['Tone']  # Tone Synthesis (lookup/sine)( 1 )
white_noise = cells['White_Noise']  # White Noise( 1 )

# %% [markdown]
# # Frequency Response Tuning

# %%
relative_paths = [['..', '..', '..', '..', '..', '..', '..', '資料科學', 'Allen Downey', 'Think DSP', 'code'],
                  ['..', '..', '..', '..', '..', 'AutoEq'],
                  ['..', '..', 'codes']]

Pathfinder.append_relative_paths(relative_paths)

# import thinkdsp
# from drc.sound import Sound, Channel, InputDevice

import time
from drc.tuners.response.equalizer import ResponseEqualizer
from drc.measurements.frequency import plot_spectrum
from drc.measurements import Sampler

# %%
# from pprint import pprint

# pprint(Sound.scan_devices(0))

# %% [markdown]
# ## Setup Source Signal

# %%
# switch to white noise
source_switch.switch(1)
invert1.enable(False)
sw_noise.switch(1)

# %% [markdown]
# ## Mute other speakers (leave targeted one alone)

# %%
sampling_rate = 48000

# %%
mute00.mute(False)
mute01.mute(True)
mute10.mute(True)
mute11.mute(True)

# %%
# with open('white noise.bin', 'br') as f:
#     data = pickle.load(f)
    
# ch = Channel(data, framerate = sampling_rate)

# %% [markdown]
# # Get Samples

# %%
def probe(target_dB = 70, plot = True):    
    fs, amps, ch = Sampler.probe(input_device_idx = 1, framerate = 48000, freq_lims = (20, 8000))        
    if plot:
        plot_spectrum(fs, amps)
        plt.plot(fs, np.ones_like(amps) * target_dB, linewidth = 3, color = 'orange') 
        
    return fs, amps, ch

# %% [markdown]
# # FIR Filter

# %%
taps_size = 256

# %%
def reset_FIR():
    coeffs = np.zeros(taps_size)
    coeffs[0] = 1.0
    fir0.set_coefficients(coeffs)

# %%
import torch
import torch.nn.functional as F
from torch import nn

class NeuralNetwork(nn.Module):

    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(1, taps_size)
        self.fc2 = nn.Linear(taps_size, taps_size)
        self.fc3 = nn.Linear(taps_size, taps_size)


    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
#         x = torch.tanh(self.fc3(x))
        x = torch.mul(torch.sigmoid(self.fc3(x)).subtract(0.5), 2)
#         x = F.normalize(x)
        return x

# %%
model = NeuralNetwork()

loss_fn = nn.MSELoss()
# loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-3)

reset_FIR()

# %%
target_dB =  72 

x = torch.ones((1, 1))


def test_cycle():
    
    coeffs = model(x)
    
    # apply filter coefficients
    fir0.set_coefficients(coeffs.flatten())
    time.sleep(1)
    print(fir0.get_coefficients()[:10])
    
    # probe and plot
    fs, amps, _ = probe(plot = False)  
    target = np.ones_like(amps) * target_dB
    plot_spectrum(fs, amps);
    plt.plot(fs, target);
     
    # train
    amps = torch.tensor(amps.reshape((1, -1)) / 100 )
    target = torch.tensor(target.reshape((1, -1)) / 100 )
    loss = loss_fn(amps, target) 
    coeffs.backward(gradient =  loss * coeffs / torch.sum(coeffs) / taps_size, retain_graph = True)
#     coeffs.backward(gradient = torch.ones_like(coeffs) * loss / taps_size , retain_graph = True)
    optimizer.step()

    return coeffs, loss

# %%
coeffs, loss = test_cycle();
print(loss);
# Out:
# [0.01000833511352539, 0.013138055801391602, -0.007651925086975098, 0.10370361804962158, 0.04532897472381592, 0.05303192138671875, 0.03842127323150635, -0.06024670600891113, 0.01212000846862793, -0.03233993053436279]
# C:\Softwares\Python\lib\site-packages\numpy\fft\_pocketfft.py:70: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)
# tensor(0.0920, dtype=torch.float64)

# %%
source_switch.switch(2)

# %%
source_switch.switch(1)

# %% [markdown]
# # Close TCP channels

# %%
tcpi_client.stop()
# Out:
# [Client set to stop.]
#
# [Connection with server ('192.168.228.36', 8086) is closed.]
